# %%
import numpy as np

# %% [markdown]
# # Training Data

# %%
training_data = np.load("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/training_data/training_data.npy")
training_bubble = np.load("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/training_data/training_bubble.npy")
training_data_concatenate = np.concatenate((training_data, training_bubble))

# %%
training_data_labels = [0] * len(training_data)
training_bubble_labels = [1] * len(training_bubble)
training_labels = np.array(training_data_labels + training_bubble_labels)

# %%
print("value of training data: ", len(training_data_concatenate))
print("value of training labels: ", len(training_labels))
# Out:
# value of training data:  4014
# value of training labels:  4014

# %%
np.save("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/training_data/training_data_concatenate", training_data_concatenate)
np.save("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/training_data/training_labels_concatenate", training_labels)

# %% [markdown]
# # Validation Data

# %%
validation_data = np.load("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/validation_data/validation_data.npy")
validation_bubble = np.load("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/validation_data/validation_bubble.npy")
validation_data_concatenate = np.concatenate((validation_data, validation_bubble))

# %%
validation_data_labels = [0] * len(validation_data)
validation_bubble_labels = [1] * len(validation_bubble)
validation_labels = np.array(validation_data_labels + validation_bubble_labels)

# %%
print("value of training data: ", len(validation_data_concatenate))
print("value of training labels: ", len(validation_labels))
# Out:
# value of training data:  48
# value of training labels:  48

# %%
np.save("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/validation_data/validation_data_concatenate", validation_data_concatenate)
np.save("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/processed_data/split_area/validation_data/validation_labels_concatenate", validation_labels)
